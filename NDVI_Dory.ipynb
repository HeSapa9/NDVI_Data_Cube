# %%
pip install "git+https://github.com/CU-ESIIL/cubedynamics.git@main"
# Out:
# Collecting git+https://github.com/CU-ESIIL/cubedynamics.git@main
#   Cloning https://github.com/CU-ESIIL/cubedynamics.git (to revision main) to /tmp/pip-req-build-wks2owzy
#   Running command git clone --filter=blob:none --quiet https://github.com/CU-ESIIL/cubedynamics.git /tmp/pip-req-build-wks2owzy
#   Resolved https://github.com/CU-ESIIL/cubedynamics.git to commit b09488505648cb6be928be774f126a118b1df06c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (2.2.6)
# Requirement already satisfied: xarray in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (2025.6.1)
# Requirement already satisfied: pandas in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (2.3.0)
# Requirement already satisfied: rasterio in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (1.4.3)
# Requirement already satisfied: rioxarray in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (0.19.0)
# Requirement already satisfied: pystac-client in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (0.8.6)
# Collecting planetary-computer (from cubedynamics==0.1.0)
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pyproj in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (3.7.1)
# Requirement already satisfied: requests in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (2.32.4)
# Requirement already satisfied: dask in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (2025.5.1)
# Collecting cubo (from cubedynamics==0.1.0)
#   Downloading cubo-2024.8.0.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (3.10.3)
# Requirement already satisfied: Pillow in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (11.2.1)
# Collecting crc32c (from cubedynamics==0.1.0)
#   Downloading crc32c-2.8-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: plotly in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (6.1.2)
# Requirement already satisfied: geopandas in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (1.1.0)
# Requirement already satisfied: shapely in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubedynamics==0.1.0) (2.1.1)
# Collecting numpy (from cubedynamics==0.1.0)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: scipy>=1.12.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from cubo->cubedynamics==0.1.0) (1.15.2)
# Collecting stackstac>=0.4.4 (from cubo->cubedynamics==0.1.0)
#   Downloading stackstac-0.5.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: click>=8.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from dask->cubedynamics==0.1.0) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from dask->cubedynamics==0.1.0) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from dask->cubedynamics==0.1.0) (2025.5.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from dask->cubedynamics==0.1.0) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from dask->cubedynamics==0.1.0) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from dask->cubedynamics==0.1.0) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from dask->cubedynamics==0.1.0) (1.0.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from dask->cubedynamics==0.1.0) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from importlib_metadata>=4.13.0->dask->cubedynamics==0.1.0) (3.23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pandas->cubedynamics==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pandas->cubedynamics==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pandas->cubedynamics==0.1.0) (2025.2)
# Requirement already satisfied: locket in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from partd>=1.4.0->dask->cubedynamics==0.1.0) (1.0.0)
# Requirement already satisfied: pydantic>=1.7.3 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from planetary-computer->cubedynamics==0.1.0) (2.11.7)
# Requirement already satisfied: pystac>=1.0.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from planetary-computer->cubedynamics==0.1.0) (1.13.0)
# Collecting python-dotenv (from planetary-computer->cubedynamics==0.1.0)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pydantic>=1.7.3->planetary-computer->cubedynamics==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pydantic>=1.7.3->planetary-computer->cubedynamics==0.1.0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pydantic>=1.7.3->planetary-computer->cubedynamics==0.1.0) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pydantic>=1.7.3->planetary-computer->cubedynamics==0.1.0) (0.4.1)
# Requirement already satisfied: jsonschema~=4.18 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from pystac[validation]>=1.10.0->pystac-client->cubedynamics==0.1.0) (4.24.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->cubedynamics==0.1.0) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->cubedynamics==0.1.0) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->cubedynamics==0.1.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->cubedynamics==0.1.0) (0.25.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->cubedynamics==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from requests->cubedynamics==0.1.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from requests->cubedynamics==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from requests->cubedynamics==0.1.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from requests->cubedynamics==0.1.0) (2025.6.15)
# Requirement already satisfied: affine in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from rasterio->cubedynamics==0.1.0) (2.4.0)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from rasterio->cubedynamics==0.1.0) (0.7.2)
# Requirement already satisfied: click-plugins in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from rasterio->cubedynamics==0.1.0) (1.1.1)
# Requirement already satisfied: pyparsing in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from rasterio->cubedynamics==0.1.0) (3.2.3)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from geopandas->cubedynamics==0.1.0) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from matplotlib->cubedynamics==0.1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from matplotlib->cubedynamics==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from matplotlib->cubedynamics==0.1.0) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from matplotlib->cubedynamics==0.1.0) (1.4.7)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/conda/envs/macrosystems/lib/python3.10/site-packages (from plotly->cubedynamics==0.1.0) (1.43.0)
# Downloading crc32c-2.8-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (79 kB)
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 119.9 MB/s eta 0:00:00
# Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Downloading stackstac-0.5.1-py3-none-any.whl (64 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Building wheels for collected packages: cubedynamics, cubo
#   Building wheel for cubedynamics (pyproject.toml) ... done
#   Created wheel for cubedynamics: filename=cubedynamics-0.1.0-py3-none-any.whl size=170241 sha256=306cdeab5700408f398b7f30a5afe09ead5b96d2d645c53258776d60b130644f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-keq9_vx2/wheels/0d/43/24/6566e59a062b5b91545f46583b0b1cba464387f607d45a0ac5
#   DEPRECATION: Building 'cubo' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'cubo'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for cubo (setup.py) ... done
#   Created wheel for cubo: filename=cubo-2024.8.0-py3-none-any.whl size=10245 sha256=da8abd29a4294e9f913be2949ad9351ab8fdda740a47678e79ccefc72b6f9391
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ac/a4/10/3d48d704cbd6c5a4d1da506f00430acf909b96fb3bed378d02
# Successfully built cubedynamics cubo
# Installing collected packages: python-dotenv, numpy, crc32c, stackstac, planetary-computer, cubo, cubedynamics
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6━━━━━━━━━━━━━━━━━━━━━━━━ 1/7 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [cubedynamics] [cubedynamics]
# Successfully installed crc32c-2.8 cubedynamics-0.1.0 cubo-2024.8.0 numpy-1.26.4 planetary-computer-1.0.0 python-dotenv-1.2.1 stackstac-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import cubedynamics as cd
from cubedynamics import pipe, verbs as v
44.05654277711424, -103.80092563274634
cube = cd.ndvi(
    lat=44.05654277711424,
    lon=-103.80092563274634,
    start="2023-06-01",
    end="2024-07-01",
)

pipe(cube) | v.plot()
# Out:
# Preparing cube… 100%
# CubePlot(data=<xarray.DataArray 'ndvi' (time: 125, y: 512, x: 512)> Size: 131MB
# dask.array<astype, shape=(125, 512, 512), dtype=float32, chunksize=(125, 256, 256), chunktype=numpy.ndarray>
# Coordinates: (12/42)
#   * time                                     (time) datetime64[ns] 1kB 2023-0...
#     id                                       (time) <U54 27kB dask.array<chunksize=(125,), meta=np.ndarray>
#   * x                                        (x) float64 4kB 5.935e+05 ... 5....
#   * y                                        (y) float64 4kB 4.881e+06 ... 4....
#     s2:datastrip_id                          (time) <U64 32kB dask.array<chunksize=(125,), meta=np.ndarray>
#     sat:orbit_state                          (time) <U10 5kB dask.array<chunksize=(125,), meta=np.ndarray>
#     ...                                       ...
#     proj:bbox                                object 8B {4900020.0, 4790220.0,...
#     gsd                                      float64 8B 10.0
#     proj:transform                           object 8B {0.0, 10.0, 499980.0, ...
#     proj:shape                               object 8B {10980}
#     epsg                                     int64 8B 32613
#     cubo:distance_from_center                (y, x) float64 2MB dask.array<chunksize=(256, 256), meta=np.ndarray>
# Attributes:
#     long_name:  Normalized Difference Vegetation Index
#     formula:    (B08 - B04) / (B08 + B04)
#     bands:      {'nir': 'B08', 'red': 'B04'}, aes=CubeAes(fill='ndvi', alpha=None, slice=None, facet=None), layers=[CubeLayer(geom='cube', data=None, aes=None, stat='identity', params={}), CubeLayer(geom='cube', data=None, aes=None, stat='identity', params={'cmap': 'viridis'})], title='ndvi', fig_title=None, legend_title=None, theme=CubeTheme(bg_color='#ffffff', panel_color='#ffffff', shadow_strength=0.15, lighting_style='studio', title_font_family="system-ui, -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif", title_font_size=20, axis_scale=0.6, legend_scale=0.6, title_color='cornflowerblue', axis_color='rgba(25, 25, 25, 0.9)', legend_color='limegreen', caption_font_scale=0.8, panel_padding=10), caption=None, size_px=None, cmap='viridis', fill_scale=ScaleFillContinuous(cmap='viridis', palette='sequential', limits=None, breaks=None, labels=None, center=None, transform=None, name=None, units=None), alpha_scale=ScaleAlphaContinuous(limits=None, range=(0.1, 1.0), name=None), thin_time_factor=4, time_label=None, x_label=None, y_label=None, time_dim='time', show_progress=True, progress_style='bar', coord=CoordCube(view='iso', elev=-10.16243563452379, azim=-39.80557109226519, zoom=1.8324482712116776, aspect=(1.0, 1.0, 1.0), time_ticks=4, space_ticks=3, time_format='%Y-%m-%d'), camera={'eye': {'x': 3.0, 'y': -2.5, 'z': -0.7}, 'up': {'x': 0.0, 'y': 0.0, 'z': 1.0}, 'center': {'x': 0.0, 'y': 0.0, 'z': 0.0}}, annotations=[], out_html='cube_da.html', facet=None, fill_mode='shell', volume_density={'time': 6, 'x': 2, 'y': 2}, volume_downsample={'time': 4, 'space': 4}, vase_mask=None, vase_outline=None, axis_rig=True, axis_meta={'time': {'name': 'Time', 'min': '02.06.2023', 'max': '01.07.2024'}})
